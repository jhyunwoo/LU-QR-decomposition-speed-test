# %%
# !nvidia-smi
# Out:
# Tue Aug 29 12:32:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    49W / 300W |    578MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
import cupy
import cupy.linalg
import cupyx.scipy
import cupyx.scipy.linalg
import cupy as cp
import time
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
lu_cal_time = np.array([])
qr_cal_time = np.array([])

for j in range(1,1000):

  # LU Decomposition
  start_time = time.time()

  for i in range(1, 1000):
    cp.random.seed(i)
    A = cp.random.rand(j, j)
    P, L, U = cupyx.scipy.linalg.lu(A)

  print("LU Decomposition", j, "array ---", time.time() - start_time, "sec")
  lu_cal_time = cp.append(lu_cal_time, cp.array([time.time() - start_time]))


  # QR Decomposition
  start_time = time.time()

  for i in range(1, 1000):
      cp.random.seed(i)
      A = cp.random.rand(j, j)
      Q, R = cupy.linalg.qr(A)

  print("QR Decomposition", j, "array ---", time.time() - start_time, "sec")
  qr_cal_time = cp.append(qr_cal_time, cp.array([time.time() - start_time]))
# Out:
# LU Decomposition 1 array --- 0.8399338722229004 sec
# QR Decomposition 1 array --- 0.48508691787719727 sec
# LU Decomposition 2 array --- 0.8443646430969238 sec
# QR Decomposition 2 array --- 0.4588596820831299 sec
# LU Decomposition 3 array --- 0.850177526473999 sec
# QR Decomposition 3 array --- 0.4765501022338867 sec
# LU Decomposition 4 array --- 1.0425384044647217 sec
# QR Decomposition 4 array --- 0.5795061588287354 sec
# LU Decomposition 5 array --- 1.2948954105377197 sec
# QR Decomposition 5 array --- 0.7083284854888916 sec
# LU Decomposition 6 array --- 1.090850591659546 sec
# QR Decomposition 6 array --- 0.4922046661376953 sec
# LU Decomposition 7 array --- 0.8594346046447754 sec
# QR Decomposition 7 array --- 0.45524144172668457 sec
# LU Decomposition 8 array --- 0.8439421653747559 sec
# QR Decomposition 8 array --- 0.45258545875549316 sec
# LU Decomposition 9 array --- 0.8336489200592041 sec
# QR Decomposition 9 array --- 0.44493722915649414 sec
# LU Decomposition 10 array --- 0.8184812068939209 sec
# QR Decomposition 10 array --- 0.4519522190093994 sec
# LU Decomposition 11 array --- 0.832082986831665 sec
# QR Decomposition 11 array --- 0.4387788772583008 sec
# LU Decomposition 12 array --- 0.8308792114257812 sec
# QR Decomposition 12 array --- 0.4564168453216553 sec
# LU Decomposition 13 array --- 0.843102216720581 sec
# QR Decomposition 13 array --- 0.4395105838775635 sec
# LU Decomposition 14 array --- 0.9154834747314453 sec
# QR Decomposition 14 array --- 0.5716168880462646 sec
# LU Decomposition 15 array --- 1.06886625289917 sec
# QR Decomposition 15 array --- 0.5303044319152832 sec
# LU Decomposition 16 array --- 0.8419725894927979 sec
# QR Decomposition 16 array --- 0.45191287994384766 sec
# LU Decomposition 17 array --- 0.9095823764801025 sec
# QR Decomposition 17 array --- 0.4609827995300293 sec
# LU Decomposition 18 array --- 0.927159309387207 sec
# QR Decomposition 18 array --- 0.4544527530670166 sec
# LU Decomposition 19 array --- 0.9035308361053467 sec
# QR Decomposition 19 array --- 0.4444291591644287 sec
# LU Decomposition 20 array --- 0.9087159633636475 sec
# QR Decomposition 20 array --- 0.45781874656677246 sec
# LU Decomposition 21 array --- 0.910083532333374 sec
# QR Decomposition 21 array --- 0.4428391456604004 sec
# LU Decomposition 22 array --- 0.8959887027740479 sec
# QR Decomposition 22 array --- 0.45038437843322754 sec
# LU Decomposition 23 array --- 1.0839600563049316 sec
# QR Decomposition 23 array --- 0.5853660106658936 sec
# LU Decomposition 24 array --- 1.126680612564087 sec
# QR Decomposition 24 array --- 0.44257140159606934 sec
# LU Decomposition 25 array --- 0.9196987152099609 sec
# QR Decomposition 25 array --- 0.463897705078125 sec
# LU Decomposition 26 array --- 0.9113795757293701 sec
# QR Decomposition 26 array --- 0.4432559013366699 sec
# LU Decomposition 27 array --- 0.9188175201416016 sec
# QR Decomposition 27 array --- 0.4647808074951172 sec
# LU Decomposition 28 array --- 0.9064319133758545 sec
# QR Decomposition 28 array --- 0.4519083499908447 sec
# LU Decomposition 29 array --- 0.8976905345916748 sec
# QR Decomposition 29 array --- 0.4456167221069336 sec
# LU Decomposition 30 array --- 0.918440580368042 sec
# QR Decomposition 30 array --- 0.4569683074951172 sec
# LU Decomposition 31 array --- 0.9104740619659424 sec
# QR Decomposition 31 array --- 0.5261507034301758 sec
# LU Decomposition 32 array --- 1.1775341033935547 sec
# QR Decomposition 32 array --- 0.5919289588928223 sec
# LU Decomposition 33 array --- 1.060666561126709 sec
# QR Decomposition 33 array --- 0.4916102886199951 sec
# LU Decomposition 34 array --- 0.9383537769317627 sec
# QR Decomposition 34 array --- 0.5005018711090088 sec
# LU Decomposition 35 array --- 0.9249212741851807 sec
# QR Decomposition 35 array --- 0.5035114288330078 sec
# LU Decomposition 36 array --- 0.9357929229736328 sec
# QR Decomposition 36 array --- 0.5013947486877441 sec
# LU Decomposition 37 array --- 0.9275937080383301 sec
# QR Decomposition 37 array --- 0.5035748481750488 sec
# LU Decomposition 38 array --- 0.9210250377655029 sec
# QR Decomposition 38 array --- 0.5035862922668457 sec
# LU Decomposition 39 array --- 0.9208955764770508 sec
# QR Decomposition 39 array --- 0.508892297744751 sec
# LU Decomposition 40 array --- 1.1239347457885742 sec
# QR Decomposition 40 array --- 0.634030818939209 sec
# LU Decomposition 41 array --- 1.1264286041259766 sec
# QR Decomposition 41 array --- 0.517329216003418 sec
# LU Decomposition 42 array --- 0.9362945556640625 sec
# QR Decomposition 42 array --- 0.516629695892334 sec
# LU Decomposition 43 array --- 0.9287252426147461 sec
# QR Decomposition 43 array --- 0.5307388305664062 sec
# LU Decomposition 44 array --- 0.9508106708526611 sec
# QR Decomposition 44 array --- 0.5248916149139404 sec
# LU Decomposition 45 array --- 0.9743514060974121 sec
# QR Decomposition 45 array --- 0.536008358001709 sec
# LU Decomposition 46 array --- 0.9218111038208008 sec
# QR Decomposition 46 array --- 0.5232052803039551 sec
# LU Decomposition 47 array --- 0.9236857891082764 sec
# QR Decomposition 47 array --- 0.530550479888916 sec
# LU Decomposition 48 array --- 1.0922460556030273 sec
# QR Decomposition 48 array --- 0.6124682426452637 sec
# LU Decomposition 49 array --- 1.1797575950622559 sec
# QR Decomposition 49 array --- 0.591963529586792 sec
# LU Decomposition 50 array --- 0.9490280151367188 sec
# QR Decomposition 50 array --- 0.5854618549346924 sec
# LU Decomposition 51 array --- 0.9747724533081055 sec
# QR Decomposition 51 array --- 0.5950310230255127 sec
# LU Decomposition 52 array --- 0.9565463066101074 sec
# QR Decomposition 52 array --- 0.5939528942108154 sec
# LU Decomposition 53 array --- 0.9695813655853271 sec
# QR Decomposition 53 array --- 0.602989673614502 sec
# LU Decomposition 54 array --- 0.9576783180236816 sec
# QR Decomposition 54 array --- 0.6035408973693848 sec
# LU Decomposition 55 array --- 0.9350464344024658 sec
# QR Decomposition 55 array --- 0.6348037719726562 sec
# LU Decomposition 56 array --- 1.2335431575775146 sec
# QR Decomposition 56 array --- 0.68668532371521 sec
# LU Decomposition 57 array --- 1.0351574420928955 sec
# QR Decomposition 57 array --- 0.6265547275543213 sec
# LU Decomposition 58 array --- 0.9770667552947998 sec
# QR Decomposition 58 array --- 0.6384973526000977 sec
# LU Decomposition 59 array --- 0.9416360855102539 sec
# QR Decomposition 59 array --- 0.6271438598632812 sec
# LU Decomposition 60 array --- 0.9431517124176025 sec
# QR Decomposition 60 array --- 0.6233811378479004 sec
# LU Decomposition 61 array --- 0.9742627143859863 sec
# QR Decomposition 61 array --- 0.6363441944122314 sec
# LU Decomposition 62 array --- 0.9621424674987793 sec
# QR Decomposition 62 array --- 0.6415150165557861 sec
# LU Decomposition 63 array --- 1.062976598739624 sec
# QR Decomposition 63 array --- 0.7090506553649902 sec
# LU Decomposition 64 array --- 1.2887120246887207 sec
# QR Decomposition 64 array --- 0.6405811309814453 sec
# LU Decomposition 65 array --- 0.9927213191986084 sec
# QR Decomposition 65 array --- 0.7169232368469238 sec
# LU Decomposition 66 array --- 0.9833700656890869 sec
# QR Decomposition 66 array --- 0.7162196636199951 sec
# LU Decomposition 67 array --- 0.9806101322174072 sec
# QR Decomposition 67 array --- 0.7249975204467773 sec
# LU Decomposition 68 array --- 1.0100336074829102 sec
# QR Decomposition 68 array --- 0.7317018508911133 sec
# LU Decomposition 69 array --- 0.9990887641906738 sec
# QR Decomposition 69 array --- 0.7223279476165771 sec
# LU Decomposition 70 array --- 1.0638020038604736 sec
# QR Decomposition 70 array --- 0.8108296394348145 sec
# LU Decomposition 71 array --- 1.2542030811309814 sec
# QR Decomposition 71 array --- 0.7335357666015625 sec
# LU Decomposition 72 array --- 0.9903974533081055 sec
# QR Decomposition 72 array --- 0.730905294418335 sec
# LU Decomposition 73 array --- 0.9944722652435303 sec
# QR Decomposition 73 array --- 0.7882261276245117 sec
# LU Decomposition 74 array --- 0.9881975650787354 sec
# QR Decomposition 74 array --- 0.7894902229309082 sec
# LU Decomposition 75 array --- 0.9944398403167725 sec
# QR Decomposition 75 array --- 0.8002300262451172 sec
# LU Decomposition 76 array --- 1.0159902572631836 sec
# QR Decomposition 76 array --- 0.799534797668457 sec
# LU Decomposition 77 array --- 1.2017438411712646 sec
# QR Decomposition 77 array --- 0.8583498001098633 sec
# LU Decomposition 78 array --- 1.1451356410980225 sec
# QR Decomposition 78 array --- 0.8053746223449707 sec
# LU Decomposition 79 array --- 1.0282328128814697 sec
# QR Decomposition 79 array --- 0.8055908679962158 sec
# LU Decomposition 80 array --- 1.0150272846221924 sec
# QR Decomposition 80 array --- 0.8223402500152588 sec
# LU Decomposition 81 array --- 1.0438165664672852 sec
# QR Decomposition 81 array --- 0.8839137554168701 sec
# LU Decomposition 82 array --- 1.037721872329712 sec
# QR Decomposition 82 array --- 0.8881473541259766 sec
# LU Decomposition 83 array --- 1.0366079807281494 sec
# QR Decomposition 83 array --- 0.9648234844207764 sec
# LU Decomposition 84 array --- 1.2876427173614502 sec
# QR Decomposition 84 array --- 0.9058101177215576 sec
# LU Decomposition 85 array --- 1.0361065864562988 sec
# QR Decomposition 85 array --- 0.8980669975280762 sec
# LU Decomposition 86 array --- 1.0417885780334473 sec
# QR Decomposition 86 array --- 0.8987245559692383 sec
# LU Decomposition 87 array --- 1.0590569972991943 sec
# QR Decomposition 87 array --- 0.9037799835205078 sec
# LU Decomposition 88 array --- 1.0703041553497314 sec
# QR Decomposition 88 array --- 0.9022965431213379 sec
# LU Decomposition 89 array --- 1.0675439834594727 sec
# QR Decomposition 89 array --- 1.0206503868103027 sec
# LU Decomposition 90 array --- 1.3207178115844727 sec
# QR Decomposition 90 array --- 0.9997689723968506 sec
# LU Decomposition 91 array --- 1.0682299137115479 sec
# QR Decomposition 91 array --- 0.9662458896636963 sec
# LU Decomposition 92 array --- 1.0572807788848877 sec
# QR Decomposition 92 array --- 0.96598219871521 sec
# LU Decomposition 93 array --- 1.0456516742706299 sec
# QR Decomposition 93 array --- 0.9665975570678711 sec
# LU Decomposition 94 array --- 1.051522970199585 sec
# QR Decomposition 94 array --- 0.9763948917388916 sec
# LU Decomposition 95 array --- 1.0675768852233887 sec
# QR Decomposition 95 array --- 1.0496375560760498 sec
# LU Decomposition 96 array --- 1.3330333232879639 sec
# QR Decomposition 96 array --- 1.0011563301086426 sec
# LU Decomposition 97 array --- 1.0964486598968506 sec
# QR Decomposition 97 array --- 1.0420238971710205 sec
# LU Decomposition 98 array --- 1.0937702655792236 sec
# QR Decomposition 98 array --- 1.0443322658538818 sec
# LU Decomposition 99 array --- 1.0991685390472412 sec
# QR Decomposition 99 array --- 1.046372652053833 sec
# LU Decomposition 100 array --- 1.0853705406188965 sec
# QR Decomposition 100 array --- 1.0467238426208496 sec
# LU Decomposition 101 array --- 1.2240588665008545 sec
# QR Decomposition 101 array --- 1.11891508102417 sec
# LU Decomposition 102 array --- 1.2599031925201416 sec
# QR Decomposition 102 array --- 1.057706594467163 sec
# LU Decomposition 103 array --- 1.146939992904663 sec
# QR Decomposition 103 array --- 1.0564165115356445 sec
# LU Decomposition 104 array --- 1.1113171577453613 sec
# QR Decomposition 104 array --- 1.0517635345458984 sec
# LU Decomposition 105 array --- 1.1176717281341553 sec
# QR Decomposition 105 array --- 1.1214337348937988 sec
# LU Decomposition 106 array --- 1.1096689701080322 sec
# QR Decomposition 106 array --- 1.1610186100006104 sec
# LU Decomposition 107 array --- 1.317591667175293 sec
# QR Decomposition 107 array --- 1.1733839511871338 sec
# LU Decomposition 108 array --- 1.1195168495178223 sec
# QR Decomposition 108 array --- 1.1288213729858398 sec
# LU Decomposition 109 array --- 1.130192756652832 sec
# QR Decomposition 109 array --- 1.1337292194366455 sec
# LU Decomposition 110 array --- 1.1176581382751465 sec
# QR Decomposition 110 array --- 1.1348481178283691 sec
# LU Decomposition 111 array --- 1.1174726486206055 sec
# QR Decomposition 111 array --- 1.1387653350830078 sec
# LU Decomposition 112 array --- 1.2881231307983398 sec
# QR Decomposition 112 array --- 1.1997933387756348 sec
# LU Decomposition 113 array --- 1.1989507675170898 sec
# QR Decomposition 113 array --- 1.1876745223999023 sec
# LU Decomposition 114 array --- 1.1635851860046387 sec
# QR Decomposition 114 array --- 1.1917142868041992 sec
# LU Decomposition 115 array --- 1.1474330425262451 sec
# QR Decomposition 115 array --- 1.192049503326416 sec
# LU Decomposition 116 array --- 1.136641025543213 sec
# QR Decomposition 116 array --- 1.1933984756469727 sec
# LU Decomposition 117 array --- 1.2154736518859863 sec
# QR Decomposition 117 array --- 1.2888522148132324 sec
# LU Decomposition 118 array --- 1.2949259281158447 sec
# QR Decomposition 118 array --- 1.1997387409210205 sec
# LU Decomposition 119 array --- 1.1670539379119873 sec
# QR Decomposition 119 array --- 1.2048964500427246 sec
# LU Decomposition 120 array --- 1.1465466022491455 sec
# QR Decomposition 120 array --- 1.2046351432800293 sec
# LU Decomposition 121 array --- 1.1488127708435059 sec
# QR Decomposition 121 array --- 1.2607381343841553 sec
# LU Decomposition 122 array --- 1.1940348148345947 sec
# QR Decomposition 122 array --- 1.400247573852539 sec
# LU Decomposition 123 array --- 1.4556875228881836 sec
# QR Decomposition 123 array --- 1.4284234046936035 sec
# LU Decomposition 124 array --- 1.2497437000274658 sec
# QR Decomposition 124 array --- 1.2728948593139648 sec
# LU Decomposition 125 array --- 1.187192440032959 sec
# QR Decomposition 125 array --- 1.2753303050994873 sec
# LU Decomposition 126 array --- 1.1672945022583008 sec
# QR Decomposition 126 array --- 1.2705416679382324 sec
# LU Decomposition 127 array --- 1.173945426940918 sec
# QR Decomposition 127 array --- 1.274029016494751 sec
# LU Decomposition 128 array --- 1.4100868701934814 sec
# QR Decomposition 128 array --- 1.2789533138275146 sec
# LU Decomposition 129 array --- 1.2047312259674072 sec
# QR Decomposition 129 array --- 0.8768963813781738 sec
# LU Decomposition 130 array --- 1.2227602005004883 sec
# QR Decomposition 130 array --- 0.8778362274169922 sec
# LU Decomposition 131 array --- 1.2161331176757812 sec
# QR Decomposition 131 array --- 0.8825085163116455 sec
# LU Decomposition 132 array --- 1.204920768737793 sec
# QR Decomposition 132 array --- 0.8884272575378418 sec
# LU Decomposition 133 array --- 1.2112066745758057 sec
# QR Decomposition 133 array --- 0.9752309322357178 sec
# LU Decomposition 134 array --- 1.4790382385253906 sec
# QR Decomposition 134 array --- 0.8999531269073486 sec
# LU Decomposition 135 array --- 1.214411973953247 sec
# QR Decomposition 135 array --- 0.904932975769043 sec
# LU Decomposition 136 array --- 1.2448148727416992 sec
# QR Decomposition 136 array --- 0.9124407768249512 sec
# LU Decomposition 137 array --- 1.2257452011108398 sec
# QR Decomposition 137 array --- 0.9176526069641113 sec
# LU Decomposition 138 array --- 1.2249336242675781 sec
# QR Decomposition 138 array --- 0.9190192222595215 sec
# LU Decomposition 139 array --- 1.367466688156128 sec
# QR Decomposition 139 array --- 1.0023987293243408 sec
# LU Decomposition 140 array --- 1.3269896507263184 sec
# QR Decomposition 140 array --- 0.929527759552002 sec
# LU Decomposition 141 array --- 1.240339756011963 sec
# QR Decomposition 141 array --- 0.9344034194946289 sec
# LU Decomposition 142 array --- 1.23707914352417 sec
# QR Decomposition 142 array --- 0.9357998371124268 sec
# LU Decomposition 143 array --- 1.2254300117492676 sec
# QR Decomposition 143 array --- 0.937716007232666 sec
# LU Decomposition 144 array --- 1.2259583473205566 sec
# QR Decomposition 144 array --- 0.9739165306091309 sec
# LU Decomposition 145 array --- 1.4924640655517578 sec
# QR Decomposition 145 array --- 1.0340874195098877 sec
# LU Decomposition 146 array --- 1.28948974609375 sec
# QR Decomposition 146 array --- 0.9992203712463379 sec
# LU Decomposition 147 array --- 1.2744591236114502 sec
# QR Decomposition 147 array --- 1.0075538158416748 sec
# LU Decomposition 148 array --- 1.2867579460144043 sec
# QR Decomposition 148 array --- 1.0069365501403809 sec
# LU Decomposition 149 array --- 1.2744324207305908 sec
# QR Decomposition 149 array --- 1.0076053142547607 sec
# LU Decomposition 150 array --- 1.4973483085632324 sec
# QR Decomposition 150 array --- 1.082460641860962 sec
# LU Decomposition 151 array --- 1.2793407440185547 sec
# QR Decomposition 151 array --- 1.0151872634887695 sec
# LU Decomposition 152 array --- 1.2882637977600098 sec
# QR Decomposition 152 array --- 1.0219800472259521 sec
# LU Decomposition 153 array --- 1.292710542678833 sec
# QR Decomposition 153 array --- 1.0328502655029297 sec
# LU Decomposition 154 array --- 1.29425048828125 sec
# QR Decomposition 154 array --- 1.0316548347473145 sec
# LU Decomposition 155 array --- 1.405987024307251 sec
# QR Decomposition 155 array --- 1.1050479412078857 sec
# LU Decomposition 156 array --- 1.3740193843841553 sec
# QR Decomposition 156 array --- 1.042043685913086 sec
# LU Decomposition 157 array --- 1.287656307220459 sec
# QR Decomposition 157 array --- 1.0478615760803223 sec
# LU Decomposition 158 array --- 1.2959139347076416 sec
# QR Decomposition 158 array --- 1.0565767288208008 sec
# LU Decomposition 159 array --- 1.3155028820037842 sec
# QR Decomposition 159 array --- 1.0664684772491455 sec
# LU Decomposition 160 array --- 1.4002912044525146 sec
# QR Decomposition 160 array --- 1.1233270168304443 sec
# LU Decomposition 161 array --- 1.4696097373962402 sec
# QR Decomposition 161 array --- 1.0761137008666992 sec
# LU Decomposition 162 array --- 1.3152015209197998 sec
# QR Decomposition 162 array --- 1.078310251235962 sec
# LU Decomposition 163 array --- 1.31783127784729 sec
# QR Decomposition 163 array --- 1.0871431827545166 sec
# LU Decomposition 164 array --- 1.3482060432434082 sec
# QR Decomposition 164 array --- 1.0950243473052979 sec
# LU Decomposition 165 array --- 1.4306094646453857 sec
# QR Decomposition 165 array --- 1.1780784130096436 sec
# LU Decomposition 166 array --- 1.4775938987731934 sec
# QR Decomposition 166 array --- 1.1027510166168213 sec
# LU Decomposition 167 array --- 1.3517916202545166 sec
# QR Decomposition 167 array --- 1.1002905368804932 sec
# LU Decomposition 168 array --- 1.381023645401001 sec
# QR Decomposition 168 array --- 1.102351188659668 sec
# LU Decomposition 169 array --- 1.3463358879089355 sec
# QR Decomposition 169 array --- 1.119385004043579 sec
# LU Decomposition 170 array --- 1.4780328273773193 sec
# QR Decomposition 170 array --- 1.20347261428833 sec
# LU Decomposition 171 array --- 1.4272840023040771 sec
# QR Decomposition 171 array --- 1.1193945407867432 sec
# LU Decomposition 172 array --- 1.3692598342895508 sec
# QR Decomposition 172 array --- 1.12691068649292 sec
# LU Decomposition 173 array --- 1.362562656402588 sec
# QR Decomposition 173 array --- 1.1345176696777344 sec
# LU Decomposition 174 array --- 1.356426477432251 sec
# QR Decomposition 174 array --- 1.142202615737915 sec
# LU Decomposition 175 array --- 1.5432453155517578 sec
# QR Decomposition 175 array --- 1.2119500637054443 sec
# LU Decomposition 176 array --- 1.3691997528076172 sec
# QR Decomposition 176 array --- 1.1411681175231934 sec
# LU Decomposition 177 array --- 1.3863706588745117 sec
# QR Decomposition 177 array --- 1.161463737487793 sec
# LU Decomposition 178 array --- 1.3951342105865479 sec
# QR Decomposition 178 array --- 1.1653797626495361 sec
# LU Decomposition 179 array --- 1.407496690750122 sec
# QR Decomposition 179 array --- 1.17215895652771 sec
# LU Decomposition 180 array --- 1.6444752216339111 sec
# QR Decomposition 180 array --- 1.2090511322021484 sec
# LU Decomposition 181 array --- 1.3996081352233887 sec
# QR Decomposition 181 array --- 1.168238878250122 sec
# LU Decomposition 182 array --- 1.402970552444458 sec
# QR Decomposition 182 array --- 1.1798863410949707 sec
# LU Decomposition 183 array --- 1.412571907043457 sec
# QR Decomposition 183 array --- 1.1772613525390625 sec
# LU Decomposition 184 array --- 1.4216065406799316 sec
# QR Decomposition 184 array --- 1.2632644176483154 sec
# LU Decomposition 185 array --- 1.6513707637786865 sec
# QR Decomposition 185 array --- 1.2006423473358154 sec
# LU Decomposition 186 array --- 1.3996050357818604 sec
# QR Decomposition 186 array --- 1.197551965713501 sec
# LU Decomposition 187 array --- 1.4143085479736328 sec
# QR Decomposition 187 array --- 1.2015235424041748 sec
# LU Decomposition 188 array --- 1.4300625324249268 sec
# QR Decomposition 188 array --- 1.2090239524841309 sec
# LU Decomposition 189 array --- 1.5470433235168457 sec
# QR Decomposition 189 array --- 1.277550458908081 sec
# LU Decomposition 190 array --- 1.4602506160736084 sec
# QR Decomposition 190 array --- 1.217299461364746 sec
# LU Decomposition 191 array --- 1.4252910614013672 sec
# QR Decomposition 191 array --- 1.2190639972686768 sec
# LU Decomposition 192 array --- 1.4202966690063477 sec
# QR Decomposition 192 array --- 1.220794677734375 sec
# LU Decomposition 193 array --- 1.443615198135376 sec
# QR Decomposition 193 array --- 1.3261823654174805 sec
# LU Decomposition 194 array --- 1.6919317245483398 sec
# QR Decomposition 194 array --- 1.3047754764556885 sec
# LU Decomposition 195 array --- 1.4732344150543213 sec
# QR Decomposition 195 array --- 1.2978386878967285 sec
# LU Decomposition 196 array --- 1.4633324146270752 sec
# QR Decomposition 196 array --- 1.3085947036743164 sec
# LU Decomposition 197 array --- 1.4767999649047852 sec
# QR Decomposition 197 array --- 1.3112995624542236 sec
# LU Decomposition 198 array --- 1.6771352291107178 sec
# QR Decomposition 198 array --- 1.3774840831756592 sec
# LU Decomposition 199 array --- 1.4811615943908691 sec
# QR Decomposition 199 array --- 1.3202462196350098 sec
# LU Decomposition 200 array --- 1.4741036891937256 sec
# QR Decomposition 200 array --- 1.317150354385376 sec
# LU Decomposition 201 array --- 1.4691476821899414 sec
# QR Decomposition 201 array --- 1.3371086120605469 sec
# LU Decomposition 202 array --- 1.5380992889404297 sec
# QR Decomposition 202 array --- 1.4104459285736084 sec
# LU Decomposition 203 array --- 1.5856428146362305 sec
# QR Decomposition 203 array --- 1.3395545482635498 sec
# LU Decomposition 204 array --- 1.503894567489624 sec
# QR Decomposition 204 array --- 1.3452296257019043 sec
# LU Decomposition 205 array --- 1.488595724105835 sec
# QR Decomposition 205 array --- 1.362534999847412 sec
# LU Decomposition 206 array --- 1.4844884872436523 sec
# QR Decomposition 206 array --- 1.4117374420166016 sec
# LU Decomposition 207 array --- 1.826871395111084 sec
# QR Decomposition 207 array --- 1.4278035163879395 sec
# LU Decomposition 208 array --- 1.6430833339691162 sec
# QR Decomposition 208 array --- 1.336916446685791 sec
# LU Decomposition 209 array --- 1.5308938026428223 sec
# QR Decomposition 209 array --- 1.3757803440093994 sec
# LU Decomposition 210 array --- 1.5321061611175537 sec
# QR Decomposition 210 array --- 1.4160068035125732 sec
# LU Decomposition 211 array --- 1.7698218822479248 sec
# QR Decomposition 211 array --- 1.3838093280792236 sec
# LU Decomposition 212 array --- 1.5316052436828613 sec
# QR Decomposition 212 array --- 1.390012264251709 sec
# LU Decomposition 213 array --- 1.538602590560913 sec
# QR Decomposition 213 array --- 1.402031660079956 sec
# LU Decomposition 214 array --- 1.5525832176208496 sec
# QR Decomposition 214 array --- 1.4146206378936768 sec
# LU Decomposition 215 array --- 1.7694144248962402 sec
# QR Decomposition 215 array --- 1.4354479312896729 sec
# LU Decomposition 216 array --- 1.5372014045715332 sec
# QR Decomposition 216 array --- 1.4095790386199951 sec
# LU Decomposition 217 array --- 1.5437495708465576 sec
# QR Decomposition 217 array --- 1.4216372966766357 sec
# LU Decomposition 218 array --- 1.5492465496063232 sec
# QR Decomposition 218 array --- 1.4321987628936768 sec
# LU Decomposition 219 array --- 1.793687343597412 sec
# QR Decomposition 219 array --- 1.4687790870666504 sec
# LU Decomposition 220 array --- 1.5461125373840332 sec
# QR Decomposition 220 array --- 1.4378993511199951 sec
# LU Decomposition 221 array --- 1.5595016479492188 sec
# QR Decomposition 221 array --- 1.4394941329956055 sec
# LU Decomposition 222 array --- 1.5567715167999268 sec
# QR Decomposition 222 array --- 1.4522361755371094 sec
# LU Decomposition 223 array --- 1.7783193588256836 sec
# QR Decomposition 223 array --- 1.522294521331787 sec
# LU Decomposition 224 array --- 1.5711896419525146 sec
# QR Decomposition 224 array --- 1.45841646194458 sec
# LU Decomposition 225 array --- 1.601625919342041 sec
# QR Decomposition 225 array --- 1.4486422538757324 sec
# LU Decomposition 226 array --- 1.5878345966339111 sec
# QR Decomposition 226 array --- 1.452989101409912 sec
# LU Decomposition 227 array --- 1.794062852859497 sec
# QR Decomposition 227 array --- 1.4952034950256348 sec
# LU Decomposition 228 array --- 1.5943944454193115 sec
# QR Decomposition 228 array --- 1.4709765911102295 sec
# LU Decomposition 229 array --- 1.6137886047363281 sec
# QR Decomposition 229 array --- 1.4785237312316895 sec
# LU Decomposition 230 array --- 1.6318702697753906 sec
# QR Decomposition 230 array --- 1.4840173721313477 sec
# LU Decomposition 231 array --- 1.8537578582763672 sec
# QR Decomposition 231 array --- 1.4965853691101074 sec
# LU Decomposition 232 array --- 1.606658935546875 sec
# QR Decomposition 232 array --- 1.4845407009124756 sec
# LU Decomposition 233 array --- 1.611689567565918 sec
# QR Decomposition 233 array --- 1.5113499164581299 sec
# LU Decomposition 234 array --- 1.6112563610076904 sec
# QR Decomposition 234 array --- 1.5389809608459473 sec
# LU Decomposition 235 array --- 1.8955833911895752 sec
# QR Decomposition 235 array --- 1.5158817768096924 sec
# LU Decomposition 236 array --- 1.6115374565124512 sec
# QR Decomposition 236 array --- 1.5235986709594727 sec
# LU Decomposition 237 array --- 1.6147832870483398 sec
# QR Decomposition 237 array --- 1.5185670852661133 sec
# LU Decomposition 238 array --- 1.6189792156219482 sec
# QR Decomposition 238 array --- 1.5695455074310303 sec
# LU Decomposition 239 array --- 1.8204929828643799 sec
# QR Decomposition 239 array --- 1.5192651748657227 sec
# LU Decomposition 240 array --- 1.634145736694336 sec
# QR Decomposition 240 array --- 1.5344951152801514 sec
# LU Decomposition 241 array --- 1.6531734466552734 sec
# QR Decomposition 241 array --- 1.565006971359253 sec
# LU Decomposition 242 array --- 1.6502716541290283 sec
# QR Decomposition 242 array --- 1.6739387512207031 sec
# LU Decomposition 243 array --- 1.7899434566497803 sec
# QR Decomposition 243 array --- 1.5558319091796875 sec
# LU Decomposition 244 array --- 1.6651647090911865 sec
# QR Decomposition 244 array --- 1.5715928077697754 sec
# LU Decomposition 245 array --- 1.674130916595459 sec
# QR Decomposition 245 array --- 1.5794522762298584 sec
# LU Decomposition 246 array --- 1.7894620895385742 sec
# QR Decomposition 246 array --- 1.6563444137573242 sec
# LU Decomposition 247 array --- 1.6742832660675049 sec
# QR Decomposition 247 array --- 1.575315237045288 sec
# LU Decomposition 248 array --- 1.6681644916534424 sec
# QR Decomposition 248 array --- 1.5977139472961426 sec
# LU Decomposition 249 array --- 1.6756610870361328 sec
# QR Decomposition 249 array --- 1.6036767959594727 sec
# LU Decomposition 250 array --- 1.93703293800354 sec
# QR Decomposition 250 array --- 1.6366450786590576 sec
# LU Decomposition 251 array --- 1.703413486480713 sec
# QR Decomposition 251 array --- 1.6123456954956055 sec
# LU Decomposition 252 array --- 1.692195177078247 sec
# QR Decomposition 252 array --- 1.6211392879486084 sec
# LU Decomposition 253 array --- 1.6960914134979248 sec
# QR Decomposition 253 array --- 1.6880958080291748 sec
# LU Decomposition 254 array --- 1.8882975578308105 sec
# QR Decomposition 254 array --- 1.6399822235107422 sec
# LU Decomposition 255 array --- 1.6883013248443604 sec
# QR Decomposition 255 array --- 1.6336047649383545 sec
# LU Decomposition 256 array --- 1.686232089996338 sec
# QR Decomposition 256 array --- 1.5483295917510986 sec
# LU Decomposition 257 array --- 1.918708086013794 sec
# QR Decomposition 257 array --- 1.661463737487793 sec
# LU Decomposition 258 array --- 1.847649335861206 sec
# QR Decomposition 258 array --- 1.6047248840332031 sec
# LU Decomposition 259 array --- 1.8513891696929932 sec
# QR Decomposition 259 array --- 1.5982065200805664 sec
# LU Decomposition 260 array --- 1.8552446365356445 sec
# QR Decomposition 260 array --- 1.630089282989502 sec
# LU Decomposition 261 array --- 2.0907554626464844 sec
# QR Decomposition 261 array --- 1.6189544200897217 sec
# LU Decomposition 262 array --- 1.8885126113891602 sec
# QR Decomposition 262 array --- 1.6295690536499023 sec
# LU Decomposition 263 array --- 1.8838732242584229 sec
# QR Decomposition 263 array --- 1.627666711807251 sec
# LU Decomposition 264 array --- 1.964529037475586 sec
# QR Decomposition 264 array --- 1.7298333644866943 sec
# LU Decomposition 265 array --- 1.8933639526367188 sec
# QR Decomposition 265 array --- 1.6485068798065186 sec
# LU Decomposition 266 array --- 1.9105868339538574 sec
# QR Decomposition 266 array --- 1.6508793830871582 sec
# LU Decomposition 267 array --- 1.920952558517456 sec
# QR Decomposition 267 array --- 1.684577465057373 sec
# LU Decomposition 268 array --- 2.106541872024536 sec
# QR Decomposition 268 array --- 1.6514477729797363 sec
# LU Decomposition 269 array --- 1.9544007778167725 sec
# QR Decomposition 269 array --- 1.6672873497009277 sec
# LU Decomposition 270 array --- 1.9488184452056885 sec
# QR Decomposition 270 array --- 1.6917579174041748 sec
# LU Decomposition 271 array --- 2.101766586303711 sec
# QR Decomposition 271 array --- 1.7344183921813965 sec
# LU Decomposition 272 array --- 1.9502103328704834 sec
# QR Decomposition 272 array --- 1.6945359706878662 sec
# LU Decomposition 273 array --- 2.252526044845581 sec
# QR Decomposition 273 array --- 1.744065523147583 sec
# LU Decomposition 274 array --- 2.0624358654022217 sec
# QR Decomposition 274 array --- 1.8108470439910889 sec
# LU Decomposition 275 array --- 1.9980876445770264 sec
# QR Decomposition 275 array --- 1.7382087707519531 sec
# LU Decomposition 276 array --- 2.0134122371673584 sec
# QR Decomposition 276 array --- 1.7636280059814453 sec
# LU Decomposition 277 array --- 2.0274171829223633 sec
# QR Decomposition 277 array --- 1.8125922679901123 sec
# LU Decomposition 278 array --- 2.1267812252044678 sec
# QR Decomposition 278 array --- 1.7673954963684082 sec
# LU Decomposition 279 array --- 2.020857572555542 sec
# QR Decomposition 279 array --- 1.7562637329101562 sec
# LU Decomposition 280 array --- 2.0139713287353516 sec
# QR Decomposition 280 array --- 1.804673433303833 sec
# LU Decomposition 281 array --- 2.236215591430664 sec
# QR Decomposition 281 array --- 1.7776763439178467 sec
# LU Decomposition 282 array --- 2.02043080329895 sec
# QR Decomposition 282 array --- 1.790349006652832 sec
# LU Decomposition 283 array --- 2.0331695079803467 sec
# QR Decomposition 283 array --- 1.7898502349853516 sec
# LU Decomposition 284 array --- 2.257991313934326 sec
# QR Decomposition 284 array --- 1.8132705688476562 sec
# LU Decomposition 285 array --- 2.031811475753784 sec
# QR Decomposition 285 array --- 1.810908555984497 sec
# LU Decomposition 286 array --- 2.0402042865753174 sec
# QR Decomposition 286 array --- 1.8135242462158203 sec
# LU Decomposition 287 array --- 2.181438684463501 sec
# QR Decomposition 287 array --- 1.843705177307129 sec
# LU Decomposition 288 array --- 2.026716470718384 sec
# QR Decomposition 288 array --- 1.8155736923217773 sec
# LU Decomposition 289 array --- 2.061600923538208 sec
# QR Decomposition 289 array --- 1.8383686542510986 sec
# LU Decomposition 290 array --- 2.1648447513580322 sec
# QR Decomposition 290 array --- 1.921992540359497 sec
# LU Decomposition 291 array --- 2.066798448562622 sec
# QR Decomposition 291 array --- 1.8285315036773682 sec
# LU Decomposition 292 array --- 2.0633509159088135 sec
# QR Decomposition 292 array --- 1.8378684520721436 sec
# LU Decomposition 293 array --- 2.09616756439209 sec
# QR Decomposition 293 array --- 1.9337642192840576 sec
# LU Decomposition 294 array --- 2.127150058746338 sec
# QR Decomposition 294 array --- 1.853898525238037 sec
# LU Decomposition 295 array --- 2.067593574523926 sec
# QR Decomposition 295 array --- 1.842890977859497 sec
# LU Decomposition 296 array --- 2.067293882369995 sec
# QR Decomposition 296 array --- 1.915621042251587 sec
# LU Decomposition 297 array --- 2.1877195835113525 sec
# QR Decomposition 297 array --- 1.8671936988830566 sec
# LU Decomposition 298 array --- 2.1003284454345703 sec
# QR Decomposition 298 array --- 1.8778538703918457 sec
# LU Decomposition 299 array --- 2.095608949661255 sec
# QR Decomposition 299 array --- 1.9216768741607666 sec
# LU Decomposition 300 array --- 2.2214479446411133 sec
# QR Decomposition 300 array --- 1.8887972831726074 sec
# LU Decomposition 301 array --- 2.1123509407043457 sec
# QR Decomposition 301 array --- 1.8861494064331055 sec
# LU Decomposition 302 array --- 2.106389284133911 sec
# QR Decomposition 302 array --- 1.9527812004089355 sec
# LU Decomposition 303 array --- 2.2125680446624756 sec
# QR Decomposition 303 array --- 1.8978946208953857 sec
# LU Decomposition 304 array --- 2.0923690795898438 sec
# QR Decomposition 304 array --- 1.9084362983703613 sec
# LU Decomposition 305 array --- 2.1277971267700195 sec
# QR Decomposition 305 array --- 1.9793117046356201 sec
# LU Decomposition 306 array --- 2.2791292667388916 sec
# QR Decomposition 306 array --- 1.9385218620300293 sec
# LU Decomposition 307 array --- 2.141155958175659 sec
# QR Decomposition 307 array --- 1.926339864730835 sec
# LU Decomposition 308 array --- 2.134150266647339 sec
# QR Decomposition 308 array --- 1.9974050521850586 sec
# LU Decomposition 309 array --- 2.2788381576538086 sec
# QR Decomposition 309 array --- 1.9669079780578613 sec
# LU Decomposition 310 array --- 2.164353847503662 sec
# QR Decomposition 310 array --- 1.9661757946014404 sec
# LU Decomposition 311 array --- 2.1598174571990967 sec
# QR Decomposition 311 array --- 2.000901222229004 sec
# LU Decomposition 312 array --- 2.267162561416626 sec
# QR Decomposition 312 array --- 1.9633090496063232 sec
# LU Decomposition 313 array --- 2.178651809692383 sec
# QR Decomposition 313 array --- 2.007875680923462 sec
# LU Decomposition 314 array --- 2.1727917194366455 sec
# QR Decomposition 314 array --- 2.068122148513794 sec
# LU Decomposition 315 array --- 2.250809669494629 sec
# QR Decomposition 315 array --- 1.9884192943572998 sec
# LU Decomposition 316 array --- 2.1878654956817627 sec
# QR Decomposition 316 array --- 2.009821891784668 sec
# LU Decomposition 317 array --- 2.1750168800354004 sec
# QR Decomposition 317 array --- 2.0864453315734863 sec
# LU Decomposition 318 array --- 2.2331504821777344 sec
# QR Decomposition 318 array --- 2.019937038421631 sec
# LU Decomposition 319 array --- 2.166316032409668 sec
# QR Decomposition 319 array --- 2.0088798999786377 sec
# LU Decomposition 320 array --- 2.2007393836975098 sec
# QR Decomposition 320 array --- 2.0742194652557373 sec
# LU Decomposition 321 array --- 2.254070281982422 sec
# QR Decomposition 321 array --- 2.1099963188171387 sec
# LU Decomposition 322 array --- 2.211122989654541 sec
# QR Decomposition 322 array --- 2.110182285308838 sec
# LU Decomposition 323 array --- 2.309739828109741 sec
# QR Decomposition 323 array --- 2.168539524078369 sec
# LU Decomposition 324 array --- 2.237212657928467 sec
# QR Decomposition 324 array --- 2.1249520778656006 sec
# LU Decomposition 325 array --- 2.249626398086548 sec
# QR Decomposition 325 array --- 2.1660315990448 sec
# LU Decomposition 326 array --- 2.8615360260009766 sec
# QR Decomposition 326 array --- 2.1759274005889893 sec
# LU Decomposition 327 array --- 2.2343621253967285 sec
# QR Decomposition 327 array --- 2.143502950668335 sec
# LU Decomposition 328 array --- 2.248626470565796 sec
# QR Decomposition 328 array --- 2.151106834411621 sec
# LU Decomposition 329 array --- 2.4686529636383057 sec
# QR Decomposition 329 array --- 2.1660354137420654 sec
# LU Decomposition 330 array --- 2.249699831008911 sec
# QR Decomposition 330 array --- 2.1652333736419678 sec
# LU Decomposition 331 array --- 2.259223461151123 sec
# QR Decomposition 331 array --- 2.229335069656372 sec
# LU Decomposition 332 array --- 2.3579139709472656 sec
# QR Decomposition 332 array --- 2.1769042015075684 sec
# LU Decomposition 333 array --- 2.2601208686828613 sec
# QR Decomposition 333 array --- 2.1907267570495605 sec
# LU Decomposition 334 array --- 2.3054566383361816 sec
# QR Decomposition 334 array --- 2.276557683944702 sec
# LU Decomposition 335 array --- 2.2614455223083496 sec
# QR Decomposition 335 array --- 2.1814656257629395 sec
# LU Decomposition 336 array --- 2.2648634910583496 sec
# QR Decomposition 336 array --- 2.163228988647461 sec
# LU Decomposition 337 array --- 2.489692449569702 sec
# QR Decomposition 337 array --- 2.262877941131592 sec
# LU Decomposition 338 array --- 2.33237361907959 sec
# QR Decomposition 338 array --- 2.2398128509521484 sec
# LU Decomposition 339 array --- 2.35017991065979 sec
# QR Decomposition 339 array --- 2.2438690662384033 sec
# LU Decomposition 340 array --- 2.5184755325317383 sec
# QR Decomposition 340 array --- 2.235077381134033 sec
# LU Decomposition 341 array --- 2.3572559356689453 sec
# QR Decomposition 341 array --- 2.2293829917907715 sec
# LU Decomposition 342 array --- 2.3530871868133545 sec
# QR Decomposition 342 array --- 2.324497938156128 sec
# LU Decomposition 343 array --- 2.377154588699341 sec
# QR Decomposition 343 array --- 2.241532564163208 sec
# LU Decomposition 344 array --- 2.3600244522094727 sec
# QR Decomposition 344 array --- 2.2580668926239014 sec
# LU Decomposition 345 array --- 2.506631851196289 sec
# QR Decomposition 345 array --- 2.314393997192383 sec
# LU Decomposition 346 array --- 2.383537769317627 sec
# QR Decomposition 346 array --- 2.304497480392456 sec
# LU Decomposition 347 array --- 2.3530375957489014 sec
# QR Decomposition 347 array --- 2.326169013977051 sec
# LU Decomposition 348 array --- 2.5054824352264404 sec
# QR Decomposition 348 array --- 2.3187108039855957 sec
# LU Decomposition 349 array --- 2.380567789077759 sec
# QR Decomposition 349 array --- 2.334974527359009 sec
# LU Decomposition 350 array --- 2.4025003910064697 sec
# QR Decomposition 350 array --- 2.4166300296783447 sec
# LU Decomposition 351 array --- 2.365034580230713 sec
# QR Decomposition 351 array --- 2.3387703895568848 sec
# LU Decomposition 352 array --- 2.3603782653808594 sec
# QR Decomposition 352 array --- 2.3427324295043945 sec
# LU Decomposition 353 array --- 2.624600410461426 sec
# QR Decomposition 353 array --- 2.3628740310668945 sec
# LU Decomposition 354 array --- 2.424710273742676 sec
# QR Decomposition 354 array --- 2.36393141746521 sec
# LU Decomposition 355 array --- 2.41373872756958 sec
# QR Decomposition 355 array --- 2.4392669200897217 sec
# LU Decomposition 356 array --- 2.4680206775665283 sec
# QR Decomposition 356 array --- 2.373173713684082 sec
# LU Decomposition 357 array --- 2.4270496368408203 sec
# QR Decomposition 357 array --- 2.3752455711364746 sec
# LU Decomposition 358 array --- 2.5880985260009766 sec
# QR Decomposition 358 array --- 2.410048007965088 sec
# LU Decomposition 359 array --- 2.4464030265808105 sec
# QR Decomposition 359 array --- 2.3806662559509277 sec
# LU Decomposition 360 array --- 2.4460983276367188 sec
# QR Decomposition 360 array --- 2.4664855003356934 sec
# LU Decomposition 361 array --- 2.5198543071746826 sec
# QR Decomposition 361 array --- 2.4383883476257324 sec
# LU Decomposition 362 array --- 2.434560537338257 sec
# QR Decomposition 362 array --- 2.43186354637146 sec
# LU Decomposition 363 array --- 2.619662046432495 sec
# QR Decomposition 363 array --- 2.453159809112549 sec
# LU Decomposition 364 array --- 2.4408273696899414 sec
# QR Decomposition 364 array --- 2.4499189853668213 sec
# LU Decomposition 365 array --- 2.472566843032837 sec
# QR Decomposition 365 array --- 2.48940372467041 sec
# LU Decomposition 366 array --- 2.5703392028808594 sec
# QR Decomposition 366 array --- 2.450700283050537 sec
# LU Decomposition 367 array --- 2.4498283863067627 sec
# QR Decomposition 367 array --- 2.458721876144409 sec
# LU Decomposition 368 array --- 2.6066248416900635 sec
# QR Decomposition 368 array --- 2.4832334518432617 sec
# LU Decomposition 369 array --- 2.496678590774536 sec
# QR Decomposition 369 array --- 2.4738640785217285 sec
# LU Decomposition 370 array --- 2.517388343811035 sec
# QR Decomposition 370 array --- 2.543774366378784 sec
# LU Decomposition 371 array --- 2.9089183807373047 sec
# QR Decomposition 371 array --- 2.47168231010437 sec
# LU Decomposition 372 array --- 2.5210869312286377 sec
# QR Decomposition 372 array --- 2.487119197845459 sec
# LU Decomposition 373 array --- 2.713923454284668 sec
# QR Decomposition 373 array --- 2.511791706085205 sec
# LU Decomposition 374 array --- 2.529510736465454 sec
# QR Decomposition 374 array --- 2.5076844692230225 sec
# LU Decomposition 375 array --- 2.5322518348693848 sec
# QR Decomposition 375 array --- 2.557103157043457 sec
# LU Decomposition 376 array --- 2.5871706008911133 sec
# QR Decomposition 376 array --- 2.5021607875823975 sec
# LU Decomposition 377 array --- 2.5464437007904053 sec
# QR Decomposition 377 array --- 2.520653009414673 sec
# LU Decomposition 378 array --- 2.7743160724639893 sec
# QR Decomposition 378 array --- 2.536724090576172 sec
# LU Decomposition 379 array --- 2.548341989517212 sec
# QR Decomposition 379 array --- 2.528916358947754 sec
# LU Decomposition 380 array --- 2.590024471282959 sec
# QR Decomposition 380 array --- 2.61118483543396 sec
# LU Decomposition 381 array --- 2.5550312995910645 sec
# QR Decomposition 381 array --- 2.5410311222076416 sec
# LU Decomposition 382 array --- 2.5617189407348633 sec
# QR Decomposition 382 array --- 2.593627691268921 sec
# LU Decomposition 383 array --- 2.671329975128174 sec
# QR Decomposition 383 array --- 2.5559253692626953 sec
# LU Decomposition 384 array --- 2.5411953926086426 sec
# QR Decomposition 384 array --- 2.4664933681488037 sec
# LU Decomposition 385 array --- 2.734407424926758 sec
# QR Decomposition 385 array --- 2.5817418098449707 sec
# LU Decomposition 386 array --- 2.6006693840026855 sec
# QR Decomposition 386 array --- 2.5411276817321777 sec
# LU Decomposition 387 array --- 2.5969862937927246 sec
# QR Decomposition 387 array --- 2.5842626094818115 sec
# LU Decomposition 388 array --- 2.628594398498535 sec
# QR Decomposition 388 array --- 2.542020082473755 sec
# LU Decomposition 389 array --- 2.609990119934082 sec
# QR Decomposition 389 array --- 2.5686585903167725 sec
# LU Decomposition 390 array --- 2.784515142440796 sec
# QR Decomposition 390 array --- 2.5743279457092285 sec
# LU Decomposition 391 array --- 2.626885175704956 sec
# QR Decomposition 391 array --- 2.5564279556274414 sec
# LU Decomposition 392 array --- 2.725930690765381 sec
# QR Decomposition 392 array --- 2.6115400791168213 sec
# LU Decomposition 393 array --- 2.6226394176483154 sec
# QR Decomposition 393 array --- 2.598330497741699 sec
# LU Decomposition 394 array --- 2.640308380126953 sec
# QR Decomposition 394 array --- 2.6707561016082764 sec
# LU Decomposition 395 array --- 2.699159622192383 sec
# QR Decomposition 395 array --- 2.5786831378936768 sec
# LU Decomposition 396 array --- 2.6350646018981934 sec
# QR Decomposition 396 array --- 2.59908390045166 sec
# LU Decomposition 397 array --- 2.8575868606567383 sec
# QR Decomposition 397 array --- 2.608619213104248 sec
# LU Decomposition 398 array --- 2.6371994018554688 sec
# QR Decomposition 398 array --- 2.6187233924865723 sec
# LU Decomposition 399 array --- 2.715059757232666 sec
# QR Decomposition 399 array --- 2.6476094722747803 sec
# LU Decomposition 400 array --- 2.6208322048187256 sec
# QR Decomposition 400 array --- 2.6153182983398438 sec
# LU Decomposition 401 array --- 2.691592216491699 sec
# QR Decomposition 401 array --- 2.738651990890503 sec
# LU Decomposition 402 array --- 2.729564905166626 sec
# QR Decomposition 402 array --- 2.6885979175567627 sec
# LU Decomposition 403 array --- 2.673905849456787 sec
# QR Decomposition 403 array --- 2.6963109970092773 sec
# LU Decomposition 404 array --- 2.857710838317871 sec
# QR Decomposition 404 array --- 2.686795234680176 sec
# LU Decomposition 405 array --- 2.693441152572632 sec
# QR Decomposition 405 array --- 2.7027499675750732 sec
# LU Decomposition 406 array --- 2.8408055305480957 sec
# QR Decomposition 406 array --- 2.7233290672302246 sec
# LU Decomposition 407 array --- 2.6950442790985107 sec
# QR Decomposition 407 array --- 2.703674554824829 sec
# LU Decomposition 408 array --- 2.728368043899536 sec
# QR Decomposition 408 array --- 2.7784011363983154 sec
# LU Decomposition 409 array --- 2.6963436603546143 sec
# QR Decomposition 409 array --- 2.7527732849121094 sec
# LU Decomposition 410 array --- 2.701413869857788 sec
# QR Decomposition 410 array --- 2.7907989025115967 sec
# LU Decomposition 411 array --- 2.773380756378174 sec
# QR Decomposition 411 array --- 2.723834753036499 sec
# LU Decomposition 412 array --- 2.707289695739746 sec
# QR Decomposition 412 array --- 2.8150782585144043 sec
# LU Decomposition 413 array --- 3.040327310562134 sec
# QR Decomposition 413 array --- 2.7606520652770996 sec
# LU Decomposition 414 array --- 2.7037835121154785 sec
# QR Decomposition 414 array --- 2.7706098556518555 sec
# LU Decomposition 415 array --- 2.7909553050994873 sec
# QR Decomposition 415 array --- 2.7977237701416016 sec
# LU Decomposition 416 array --- 2.6981215476989746 sec
# QR Decomposition 416 array --- 2.766376256942749 sec
# LU Decomposition 417 array --- 2.752711057662964 sec
# QR Decomposition 417 array --- 2.868588447570801 sec
# LU Decomposition 418 array --- 2.7538740634918213 sec
# QR Decomposition 418 array --- 2.793684959411621 sec
# LU Decomposition 419 array --- 2.7741031646728516 sec
# QR Decomposition 419 array --- 2.8224880695343018 sec
# LU Decomposition 420 array --- 2.8554704189300537 sec
# QR Decomposition 420 array --- 2.7922229766845703 sec
# LU Decomposition 421 array --- 2.7680342197418213 sec
# QR Decomposition 421 array --- 2.8021602630615234 sec
# LU Decomposition 422 array --- 2.9498660564422607 sec
# QR Decomposition 422 array --- 2.7975716590881348 sec
# LU Decomposition 423 array --- 2.766913414001465 sec
# QR Decomposition 423 array --- 2.807751178741455 sec
# LU Decomposition 424 array --- 2.952749013900757 sec
# QR Decomposition 424 array --- 2.832540273666382 sec
# LU Decomposition 425 array --- 2.7925922870635986 sec
# QR Decomposition 425 array --- 2.825913906097412 sec
# LU Decomposition 426 array --- 2.8707032203674316 sec
# QR Decomposition 426 array --- 2.868694543838501 sec
# LU Decomposition 427 array --- 2.7874395847320557 sec
# QR Decomposition 427 array --- 2.8349101543426514 sec
# LU Decomposition 428 array --- 2.784353256225586 sec
# QR Decomposition 428 array --- 2.907045364379883 sec
# LU Decomposition 429 array --- 2.794027805328369 sec
# QR Decomposition 429 array --- 2.847883939743042 sec
# LU Decomposition 430 array --- 2.8043322563171387 sec
# QR Decomposition 430 array --- 2.9219279289245605 sec
# LU Decomposition 431 array --- 2.836176633834839 sec
# QR Decomposition 431 array --- 2.851790189743042 sec
# LU Decomposition 432 array --- 2.788090229034424 sec
# QR Decomposition 432 array --- 2.8869528770446777 sec
# LU Decomposition 433 array --- 2.9828603267669678 sec
# QR Decomposition 433 array --- 2.896404266357422 sec
# LU Decomposition 434 array --- 2.8266429901123047 sec
# QR Decomposition 434 array --- 2.903627395629883 sec
# LU Decomposition 435 array --- 3.0464353561401367 sec
# QR Decomposition 435 array --- 2.877363681793213 sec
# LU Decomposition 436 array --- 2.8455352783203125 sec
# QR Decomposition 436 array --- 2.9008564949035645 sec
# LU Decomposition 437 array --- 3.0476553440093994 sec
# QR Decomposition 437 array --- 2.9149746894836426 sec
# LU Decomposition 438 array --- 2.8599393367767334 sec
# QR Decomposition 438 array --- 2.9345767498016357 sec
# LU Decomposition 439 array --- 3.0024712085723877 sec
# QR Decomposition 439 array --- 2.9305496215820312 sec
# LU Decomposition 440 array --- 2.8606162071228027 sec
# QR Decomposition 440 array --- 2.92496919631958 sec
# LU Decomposition 441 array --- 2.9566426277160645 sec
# QR Decomposition 441 array --- 2.9939563274383545 sec
# LU Decomposition 442 array --- 2.8774075508117676 sec
# QR Decomposition 442 array --- 2.9720423221588135 sec
# LU Decomposition 443 array --- 2.904756784439087 sec
# QR Decomposition 443 array --- 3.007263660430908 sec
# LU Decomposition 444 array --- 2.887584686279297 sec
# QR Decomposition 444 array --- 2.9624316692352295 sec
# LU Decomposition 445 array --- 2.895979166030884 sec
# QR Decomposition 445 array --- 3.038331985473633 sec
# LU Decomposition 446 array --- 2.890106439590454 sec
# QR Decomposition 446 array --- 2.982825756072998 sec
# LU Decomposition 447 array --- 2.878347873687744 sec
# QR Decomposition 447 array --- 3.010709762573242 sec
# LU Decomposition 448 array --- 2.8954713344573975 sec
# QR Decomposition 448 array --- 2.9466755390167236 sec
# LU Decomposition 449 array --- 2.931037187576294 sec
# QR Decomposition 449 array --- 3.099247932434082 sec
# ...
# QR Decomposition 849 array --- 6.4947593212127686 sec
# LU Decomposition 850 array --- 6.246473550796509 sec
# QR Decomposition 850 array --- 6.506884336471558 sec
# LU Decomposition 851 array --- 6.233097791671753 sec
# QR Decomposition 851 array --- 6.470491409301758 sec
# LU Decomposition 852 array --- 6.185029983520508 sec
# QR Decomposition 852 array --- 6.484477519989014 sec
# LU Decomposition 853 array --- 6.171680450439453 sec
# QR Decomposition 853 array --- 6.518909215927124 sec
# LU Decomposition 854 array --- 6.236124753952026 sec
# QR Decomposition 854 array --- 6.597090721130371 sec
# LU Decomposition 855 array --- 6.443645477294922 sec
# QR Decomposition 855 array --- 6.501658916473389 sec
# LU Decomposition 856 array --- 6.201642751693726 sec
# QR Decomposition 856 array --- 6.520118236541748 sec
# LU Decomposition 857 array --- 6.230759382247925 sec
# QR Decomposition 857 array --- 6.541623830795288 sec
# LU Decomposition 858 array --- 6.179025411605835 sec
# QR Decomposition 858 array --- 6.56740403175354 sec
# LU Decomposition 859 array --- 6.179169178009033 sec
# QR Decomposition 859 array --- 6.545458793640137 sec
# LU Decomposition 860 array --- 6.210615158081055 sec
# QR Decomposition 860 array --- 6.579976320266724 sec
# LU Decomposition 861 array --- 6.2482545375823975 sec
# QR Decomposition 861 array --- 6.607253551483154 sec
# LU Decomposition 862 array --- 6.221007347106934 sec
# QR Decomposition 862 array --- 6.623003244400024 sec
# LU Decomposition 863 array --- 6.208307504653931 sec
# QR Decomposition 863 array --- 6.585181951522827 sec
# LU Decomposition 864 array --- 6.206443786621094 sec
# QR Decomposition 864 array --- 6.593130826950073 sec
# LU Decomposition 865 array --- 6.366800308227539 sec
# QR Decomposition 865 array --- 6.6397669315338135 sec
# LU Decomposition 866 array --- 6.420198678970337 sec
# QR Decomposition 866 array --- 6.618818283081055 sec
# LU Decomposition 867 array --- 6.490336894989014 sec
# QR Decomposition 867 array --- 6.576375722885132 sec
# LU Decomposition 868 array --- 6.516240119934082 sec
# QR Decomposition 868 array --- 6.599376440048218 sec
# LU Decomposition 869 array --- 6.532362222671509 sec
# QR Decomposition 869 array --- 6.620771169662476 sec
# LU Decomposition 870 array --- 6.537843465805054 sec
# QR Decomposition 870 array --- 6.63569974899292 sec
# LU Decomposition 871 array --- 6.560342073440552 sec
# QR Decomposition 871 array --- 6.6252899169921875 sec
# LU Decomposition 872 array --- 6.586751222610474 sec
# QR Decomposition 872 array --- 6.653191089630127 sec
# LU Decomposition 873 array --- 6.506577253341675 sec
# QR Decomposition 873 array --- 6.820624828338623 sec
# LU Decomposition 874 array --- 6.432462215423584 sec
# QR Decomposition 874 array --- 6.737420082092285 sec
# LU Decomposition 875 array --- 6.3582985401153564 sec
# QR Decomposition 875 array --- 6.703764200210571 sec
# LU Decomposition 876 array --- 6.34755539894104 sec
# QR Decomposition 876 array --- 6.725379705429077 sec
# LU Decomposition 877 array --- 6.390451192855835 sec
# QR Decomposition 877 array --- 6.735739231109619 sec
# LU Decomposition 878 array --- 6.345936059951782 sec
# QR Decomposition 878 array --- 6.738127946853638 sec
# LU Decomposition 879 array --- 6.345094442367554 sec
# QR Decomposition 879 array --- 6.722325801849365 sec
# LU Decomposition 880 array --- 6.349839687347412 sec
# QR Decomposition 880 array --- 6.71297812461853 sec
# LU Decomposition 881 array --- 6.559092998504639 sec
# QR Decomposition 881 array --- 6.762627363204956 sec
# LU Decomposition 882 array --- 6.592911243438721 sec
# QR Decomposition 882 array --- 6.744459629058838 sec
# LU Decomposition 883 array --- 6.6057517528533936 sec
# QR Decomposition 883 array --- 6.710195541381836 sec
# LU Decomposition 884 array --- 6.618049383163452 sec
# QR Decomposition 884 array --- 6.731168746948242 sec
# LU Decomposition 885 array --- 6.6018781661987305 sec
# QR Decomposition 885 array --- 6.749933242797852 sec
# LU Decomposition 886 array --- 6.6393723487854 sec
# QR Decomposition 886 array --- 6.790481805801392 sec
# LU Decomposition 887 array --- 6.5475172996521 sec
# QR Decomposition 887 array --- 6.795065879821777 sec
# LU Decomposition 888 array --- 6.489316463470459 sec
# QR Decomposition 888 array --- 6.807792663574219 sec
# LU Decomposition 889 array --- 6.469209671020508 sec
# QR Decomposition 889 array --- 6.8542304039001465 sec
# LU Decomposition 890 array --- 6.4639787673950195 sec
# QR Decomposition 890 array --- 6.860182762145996 sec
# LU Decomposition 891 array --- 7.005767107009888 sec
# QR Decomposition 891 array --- 6.856153726577759 sec
# LU Decomposition 892 array --- 6.560420751571655 sec
# QR Decomposition 892 array --- 7.009231328964233 sec
# LU Decomposition 893 array --- 6.612732172012329 sec
# QR Decomposition 893 array --- 6.862787485122681 sec
# LU Decomposition 894 array --- 6.663474082946777 sec
# QR Decomposition 894 array --- 6.8432087898254395 sec
# LU Decomposition 895 array --- 6.6812684535980225 sec
# QR Decomposition 895 array --- 6.7967400550842285 sec
# LU Decomposition 896 array --- 6.611274003982544 sec
# QR Decomposition 896 array --- 6.741109371185303 sec
# LU Decomposition 897 array --- 6.7269392013549805 sec
# QR Decomposition 897 array --- 6.858622074127197 sec
# LU Decomposition 898 array --- 6.660562515258789 sec
# QR Decomposition 898 array --- 6.90191912651062 sec
# LU Decomposition 899 array --- 6.555197238922119 sec
# QR Decomposition 899 array --- 6.870269536972046 sec
# LU Decomposition 900 array --- 6.528872728347778 sec
# QR Decomposition 900 array --- 6.8991944789886475 sec
# LU Decomposition 901 array --- 6.56273341178894 sec
# QR Decomposition 901 array --- 6.909816741943359 sec
# LU Decomposition 902 array --- 6.558925628662109 sec
# QR Decomposition 902 array --- 6.927879333496094 sec
# LU Decomposition 903 array --- 6.611488580703735 sec
# QR Decomposition 903 array --- 6.904830455780029 sec
# LU Decomposition 904 array --- 6.7444233894348145 sec
# QR Decomposition 904 array --- 6.879486799240112 sec
# LU Decomposition 905 array --- 6.743703126907349 sec
# QR Decomposition 905 array --- 6.920334577560425 sec
# LU Decomposition 906 array --- 6.7396080493927 sec
# QR Decomposition 906 array --- 6.94025444984436 sec
# LU Decomposition 907 array --- 6.730422735214233 sec
# QR Decomposition 907 array --- 6.90721869468689 sec
# LU Decomposition 908 array --- 6.644473552703857 sec
# QR Decomposition 908 array --- 6.953632354736328 sec
# LU Decomposition 909 array --- 6.585500240325928 sec
# QR Decomposition 909 array --- 6.986137628555298 sec
# LU Decomposition 910 array --- 6.595341920852661 sec
# QR Decomposition 910 array --- 6.998254299163818 sec
# LU Decomposition 911 array --- 6.853649377822876 sec
# QR Decomposition 911 array --- 6.980989933013916 sec
# LU Decomposition 912 array --- 6.6426615715026855 sec
# QR Decomposition 912 array --- 6.985621213912964 sec
# LU Decomposition 913 array --- 6.953985214233398 sec
# QR Decomposition 913 array --- 7.073632717132568 sec
# LU Decomposition 914 array --- 6.874614000320435 sec
# QR Decomposition 914 array --- 7.065050840377808 sec
# LU Decomposition 915 array --- 6.912229061126709 sec
# QR Decomposition 915 array --- 7.05549430847168 sec
# LU Decomposition 916 array --- 6.909283638000488 sec
# QR Decomposition 916 array --- 7.093319892883301 sec
# LU Decomposition 917 array --- 6.804035902023315 sec
# QR Decomposition 917 array --- 7.142786026000977 sec
# LU Decomposition 918 array --- 6.727827072143555 sec
# QR Decomposition 918 array --- 7.144862413406372 sec
# LU Decomposition 919 array --- 6.741558313369751 sec
# QR Decomposition 919 array --- 7.1206910610198975 sec
# LU Decomposition 920 array --- 6.82728910446167 sec
# QR Decomposition 920 array --- 7.110138416290283 sec
# LU Decomposition 921 array --- 6.94146728515625 sec
# QR Decomposition 921 array --- 7.165509462356567 sec
# LU Decomposition 922 array --- 6.957552671432495 sec
# QR Decomposition 922 array --- 7.180834770202637 sec
# LU Decomposition 923 array --- 6.9820556640625 sec
# QR Decomposition 923 array --- 7.169167995452881 sec
# LU Decomposition 924 array --- 6.893294334411621 sec
# QR Decomposition 924 array --- 7.208155155181885 sec
# LU Decomposition 925 array --- 6.780974864959717 sec
# QR Decomposition 925 array --- 7.216559648513794 sec
# LU Decomposition 926 array --- 6.7715394496917725 sec
# QR Decomposition 926 array --- 7.224798202514648 sec
# LU Decomposition 927 array --- 6.783441543579102 sec
# QR Decomposition 927 array --- 7.173518896102905 sec
# LU Decomposition 928 array --- 6.918559551239014 sec
# QR Decomposition 928 array --- 7.215390682220459 sec
# LU Decomposition 929 array --- 7.066659212112427 sec
# QR Decomposition 929 array --- 7.219181060791016 sec
# LU Decomposition 930 array --- 7.057279109954834 sec
# QR Decomposition 930 array --- 7.23872447013855 sec
# LU Decomposition 931 array --- 6.973076581954956 sec
# QR Decomposition 931 array --- 7.2348456382751465 sec
# LU Decomposition 932 array --- 6.88627815246582 sec
# QR Decomposition 932 array --- 7.2418670654296875 sec
# LU Decomposition 933 array --- 6.880357265472412 sec
# QR Decomposition 933 array --- 7.286344289779663 sec
# LU Decomposition 934 array --- 6.991989612579346 sec
# QR Decomposition 934 array --- 7.2720184326171875 sec
# LU Decomposition 935 array --- 7.04595685005188 sec
# QR Decomposition 935 array --- 7.212073802947998 sec
# LU Decomposition 936 array --- 7.021146297454834 sec
# QR Decomposition 936 array --- 7.221825838088989 sec
# LU Decomposition 937 array --- 7.023257732391357 sec
# QR Decomposition 937 array --- 7.342751741409302 sec
# LU Decomposition 938 array --- 6.894745111465454 sec
# QR Decomposition 938 array --- 7.349390029907227 sec
# LU Decomposition 939 array --- 6.8917906284332275 sec
# QR Decomposition 939 array --- 7.320260286331177 sec
# LU Decomposition 940 array --- 6.950608491897583 sec
# QR Decomposition 940 array --- 7.324181079864502 sec
# LU Decomposition 941 array --- 7.0776965618133545 sec
# QR Decomposition 941 array --- 7.3132164478302 sec
# LU Decomposition 942 array --- 7.032817602157593 sec
# QR Decomposition 942 array --- 7.312989711761475 sec
# LU Decomposition 943 array --- 6.996340990066528 sec
# QR Decomposition 943 array --- 7.306293487548828 sec
# LU Decomposition 944 array --- 6.904682159423828 sec
# QR Decomposition 944 array --- 7.338396787643433 sec
# LU Decomposition 945 array --- 7.017202854156494 sec
# QR Decomposition 945 array --- 7.434877872467041 sec
# LU Decomposition 946 array --- 7.091824531555176 sec
# QR Decomposition 946 array --- 7.474913597106934 sec
# LU Decomposition 947 array --- 7.175486326217651 sec
# QR Decomposition 947 array --- 7.337303876876831 sec
# LU Decomposition 948 array --- 7.110708951950073 sec
# QR Decomposition 948 array --- 7.367592811584473 sec
# LU Decomposition 949 array --- 7.178523063659668 sec
# QR Decomposition 949 array --- 7.447747468948364 sec
# LU Decomposition 950 array --- 7.029241323471069 sec
# QR Decomposition 950 array --- 7.453964948654175 sec
# LU Decomposition 951 array --- 7.031697511672974 sec
# QR Decomposition 951 array --- 7.421616554260254 sec
# LU Decomposition 952 array --- 7.187613010406494 sec
# QR Decomposition 952 array --- 7.410240888595581 sec
# LU Decomposition 953 array --- 7.232684373855591 sec
# QR Decomposition 953 array --- 7.460520505905151 sec
# LU Decomposition 954 array --- 7.256824016571045 sec
# QR Decomposition 954 array --- 7.509675979614258 sec
# LU Decomposition 955 array --- 7.084081649780273 sec
# QR Decomposition 955 array --- 7.472477197647095 sec
# LU Decomposition 956 array --- 7.0300891399383545 sec
# QR Decomposition 956 array --- 7.509369611740112 sec
# LU Decomposition 957 array --- 7.149553060531616 sec
# QR Decomposition 957 array --- 7.496699810028076 sec
# LU Decomposition 958 array --- 7.25671124458313 sec
# QR Decomposition 958 array --- 7.512234926223755 sec
# LU Decomposition 959 array --- 7.231328964233398 sec
# QR Decomposition 959 array --- 7.494305849075317 sec
# LU Decomposition 960 array --- 7.090128421783447 sec
# QR Decomposition 960 array --- 7.505424737930298 sec
# LU Decomposition 961 array --- 7.157500505447388 sec
# QR Decomposition 961 array --- 7.684030055999756 sec
# LU Decomposition 962 array --- 7.2874391078948975 sec
# QR Decomposition 962 array --- 7.67966628074646 sec
# LU Decomposition 963 array --- 7.3723132610321045 sec
# QR Decomposition 963 array --- 7.613496780395508 sec
# LU Decomposition 964 array --- 7.360260248184204 sec
# QR Decomposition 964 array --- 7.67488956451416 sec
# LU Decomposition 965 array --- 7.212538242340088 sec
# QR Decomposition 965 array --- 7.70616602897644 sec
# LU Decomposition 966 array --- 7.345849275588989 sec
# QR Decomposition 966 array --- 7.709648132324219 sec
# LU Decomposition 967 array --- 7.34589409828186 sec
# QR Decomposition 967 array --- 7.653062105178833 sec
# LU Decomposition 968 array --- 7.326880216598511 sec
# QR Decomposition 968 array --- 7.666115999221802 sec
# LU Decomposition 969 array --- 7.298591136932373 sec
# QR Decomposition 969 array --- 7.748446702957153 sec
# LU Decomposition 970 array --- 7.164789199829102 sec
# QR Decomposition 970 array --- 7.753080129623413 sec
# LU Decomposition 971 array --- 7.271015882492065 sec
# QR Decomposition 971 array --- 7.702751398086548 sec
# LU Decomposition 972 array --- 7.375640630722046 sec
# QR Decomposition 972 array --- 7.699580192565918 sec
# LU Decomposition 973 array --- 7.424733400344849 sec
# QR Decomposition 973 array --- 7.743428945541382 sec
# LU Decomposition 974 array --- 7.252883672714233 sec
# QR Decomposition 974 array --- 7.76459264755249 sec
# LU Decomposition 975 array --- 7.185257434844971 sec
# QR Decomposition 975 array --- 7.745359420776367 sec
# LU Decomposition 976 array --- 7.37883186340332 sec
# QR Decomposition 976 array --- 7.689493417739868 sec
# LU Decomposition 977 array --- 7.460307836532593 sec
# QR Decomposition 977 array --- 7.824426889419556 sec
# LU Decomposition 978 array --- 7.414084196090698 sec
# QR Decomposition 978 array --- 7.844510316848755 sec
# LU Decomposition 979 array --- 7.273314714431763 sec
# QR Decomposition 979 array --- 7.819397449493408 sec
# LU Decomposition 980 array --- 7.406981468200684 sec
# QR Decomposition 980 array --- 7.815415859222412 sec
# LU Decomposition 981 array --- 7.4612181186676025 sec
# QR Decomposition 981 array --- 7.8073179721832275 sec
# LU Decomposition 982 array --- 7.448946714401245 sec
# QR Decomposition 982 array --- 7.840327024459839 sec
# LU Decomposition 983 array --- 7.278061866760254 sec
# QR Decomposition 983 array --- 7.811027526855469 sec
# LU Decomposition 984 array --- 7.37526273727417 sec
# QR Decomposition 984 array --- 7.8289666175842285 sec
# LU Decomposition 985 array --- 7.4912543296813965 sec
# QR Decomposition 985 array --- 7.856543302536011 sec
# LU Decomposition 986 array --- 7.707934141159058 sec
# QR Decomposition 986 array --- 7.910749197006226 sec
# LU Decomposition 987 array --- 7.3050477504730225 sec
# QR Decomposition 987 array --- 7.8686912059783936 sec
# LU Decomposition 988 array --- 7.3635008335113525 sec
# QR Decomposition 988 array --- 7.879593133926392 sec
# LU Decomposition 989 array --- 7.471835374832153 sec
# QR Decomposition 989 array --- 7.872005939483643 sec
# LU Decomposition 990 array --- 7.501981258392334 sec
# QR Decomposition 990 array --- 7.913738250732422 sec
# LU Decomposition 991 array --- 7.28534460067749 sec
# QR Decomposition 991 array --- 7.891889810562134 sec
# LU Decomposition 992 array --- 7.317841053009033 sec
# QR Decomposition 992 array --- 7.869562387466431 sec
# LU Decomposition 993 array --- 7.558668613433838 sec
# QR Decomposition 993 array --- 7.8974289894104 sec
# LU Decomposition 994 array --- 7.577190399169922 sec
# QR Decomposition 994 array --- 7.952320337295532 sec
# LU Decomposition 995 array --- 7.390535116195679 sec
# QR Decomposition 995 array --- 7.9355645179748535 sec
# LU Decomposition 996 array --- 7.437854528427124 sec
# QR Decomposition 996 array --- 7.948553085327148 sec
# LU Decomposition 997 array --- 7.592059850692749 sec
# QR Decomposition 997 array --- 7.931772947311401 sec
# LU Decomposition 998 array --- 7.602585792541504 sec
# QR Decomposition 998 array --- 7.9681055545806885 sec
# LU Decomposition 999 array --- 7.414992332458496 sec
# QR Decomposition 999 array --- 7.951674938201904 sec

# %%
x = np.arange(1,1000)
y_lu = lu_cal_time.get()
y_qr = qr_cal_time.get()
plt.figure(figsize=(10,7))
plt.plot(x, y_lu, x, y_qr, 'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x7a9b85f25780>,
#  <matplotlib.lines.Line2D at 0x7a9b85f257e0>]

# %%
for i in range(1, 999):
  if lu_cal_time[i]<qr_cal_time[i]:
    print(i, "lu is better")
# Out:
# 104 lu is better
# 105 lu is better
# 107 lu is better
# 108 lu is better
# 109 lu is better
# 110 lu is better
# 113 lu is better
# 114 lu is better
# 115 lu is better
# 116 lu is better
# 118 lu is better
# 119 lu is better
# 120 lu is better
# 121 lu is better
# 123 lu is better
# 124 lu is better
# 125 lu is better
# 126 lu is better
# 241 lu is better
# 349 lu is better
# 354 lu is better
# 359 lu is better
# 363 lu is better
# 364 lu is better
# 366 lu is better
# 369 lu is better
# 374 lu is better
# 379 lu is better
# 381 lu is better
# 393 lu is better
# 400 lu is better
# 402 lu is better
# 404 lu is better
# 406 lu is better
# 407 lu is better
# 408 lu is better
# 409 lu is better
# 411 lu is better
# 413 lu is better
# 414 lu is better
# 415 lu is better
# 416 lu is better
# 417 lu is better
# 418 lu is better
# 420 lu is better
# 422 lu is better
# 424 lu is better
# 426 lu is better
# 427 lu is better
# 428 lu is better
# 429 lu is better
# 430 lu is better
# 431 lu is better
# 433 lu is better
# 435 lu is better
# 437 lu is better
# 439 lu is better
# 440 lu is better
# 441 lu is better
# 442 lu is better
# 443 lu is better
# 444 lu is better
# 445 lu is better
# 446 lu is better
# 447 lu is better
# 448 lu is better
# 449 lu is better
# 450 lu is better
# 451 lu is better
# 452 lu is better
# 453 lu is better
# 454 lu is better
# 455 lu is better
# 456 lu is better
# 457 lu is better
# 458 lu is better
# 459 lu is better
# 460 lu is better
# 461 lu is better
# 462 lu is better
# 463 lu is better
# 464 lu is better
# 465 lu is better
# 466 lu is better
# 467 lu is better
# 468 lu is better
# 469 lu is better
# 470 lu is better
# 471 lu is better
# 472 lu is better
# 473 lu is better
# 474 lu is better
# 475 lu is better
# 476 lu is better
# 477 lu is better
# 478 lu is better
# 479 lu is better
# 480 lu is better
# 481 lu is better
# 482 lu is better
# 483 lu is better
# 484 lu is better
# 485 lu is better
# 486 lu is better
# 487 lu is better
# 488 lu is better
# 489 lu is better
# 490 lu is better
# 491 lu is better
# 493 lu is better
# 494 lu is better
# 495 lu is better
# 496 lu is better
# 497 lu is better
# 498 lu is better
# 499 lu is better
# 500 lu is better
# 501 lu is better
# 502 lu is better
# 503 lu is better
# 504 lu is better
# 505 lu is better
# 506 lu is better
# 507 lu is better
# 508 lu is better
# 509 lu is better
# 510 lu is better
# 511 lu is better
# 512 lu is better
# 513 lu is better
# 514 lu is better
# 515 lu is better
# 517 lu is better
# 519 lu is better
# 520 lu is better
# 521 lu is better
# 522 lu is better
# 524 lu is better
# 526 lu is better
# 527 lu is better
# 528 lu is better
# 529 lu is better
# 531 lu is better
# 533 lu is better
# 534 lu is better
# 536 lu is better
# 538 lu is better
# 539 lu is better
# 540 lu is better
# 541 lu is better
# 543 lu is better
# 544 lu is better
# 545 lu is better
# 546 lu is better
# 548 lu is better
# 550 lu is better
# 551 lu is better
# 553 lu is better
# 554 lu is better
# 555 lu is better
# 556 lu is better
# 558 lu is better
# 559 lu is better
# 561 lu is better
# 562 lu is better
# 563 lu is better
# 564 lu is better
# 566 lu is better
# 567 lu is better
# 569 lu is better
# 570 lu is better
# 571 lu is better
# 572 lu is better
# 573 lu is better
# 574 lu is better
# 575 lu is better
# 577 lu is better
# 580 lu is better
# 581 lu is better
# 583 lu is better
# 584 lu is better
# 586 lu is better
# 587 lu is better
# 589 lu is better
# 590 lu is better
# 591 lu is better
# 592 lu is better
# 593 lu is better
# 595 lu is better
# 596 lu is better
# 598 lu is better
# 599 lu is better
# 601 lu is better
# 602 lu is better
# 604 lu is better
# 607 lu is better
# 608 lu is better
# 610 lu is better
# 611 lu is better
# 613 lu is better
# 614 lu is better
# 615 lu is better
# 617 lu is better
# 618 lu is better
# 620 lu is better
# 621 lu is better
# 623 lu is better
# 624 lu is better
# 625 lu is better
# 627 lu is better
# 628 lu is better
# 630 lu is better
# 632 lu is better
# 634 lu is better
# 635 lu is better
# 637 lu is better
# 638 lu is better
# 639 lu is better
# 641 lu is better
# 642 lu is better
# 643 lu is better
# 645 lu is better
# 646 lu is better
# 648 lu is better
# 649 lu is better
# 650 lu is better
# 652 lu is better
# 653 lu is better
# 654 lu is better
# 657 lu is better
# 658 lu is better
# 660 lu is better
# 661 lu is better
# 662 lu is better
# 664 lu is better
# 665 lu is better
# 666 lu is better
# 668 lu is better
# 669 lu is better
# 670 lu is better
# 671 lu is better
# 673 lu is better
# 674 lu is better
# 675 lu is better
# 677 lu is better
# 678 lu is better
# 679 lu is better
# 682 lu is better
# 683 lu is better
# 684 lu is better
# 685 lu is better
# 686 lu is better
# 687 lu is better
# 688 lu is better
# 691 lu is better
# 692 lu is better
# 693 lu is better
# 696 lu is better
# 697 lu is better
# 698 lu is better
# 701 lu is better
# 702 lu is better
# 703 lu is better
# 704 lu is better
# 706 lu is better
# 707 lu is better
# 708 lu is better
# 709 lu is better
# 711 lu is better
# 712 lu is better
# 713 lu is better
# 714 lu is better
# 715 lu is better
# 716 lu is better
# 717 lu is better
# 718 lu is better
# 719 lu is better
# 720 lu is better
# 721 lu is better
# 722 lu is better
# 723 lu is better
# 724 lu is better
# 725 lu is better
# 726 lu is better
# 727 lu is better
# 728 lu is better
# 729 lu is better
# 730 lu is better
# 731 lu is better
# 732 lu is better
# 733 lu is better
# 734 lu is better
# 735 lu is better
# 736 lu is better
# 737 lu is better
# 738 lu is better
# 739 lu is better
# 740 lu is better
# 741 lu is better
# 743 lu is better
# 744 lu is better
# 745 lu is better
# 746 lu is better
# 747 lu is better
# 748 lu is better
# 749 lu is better
# 750 lu is better
# 752 lu is better
# 753 lu is better
# 754 lu is better
# 755 lu is better
# 756 lu is better
# 757 lu is better
# 759 lu is better
# 760 lu is better
# 761 lu is better
# 762 lu is better
# 763 lu is better
# 764 lu is better
# 765 lu is better
# 766 lu is better
# 767 lu is better
# 768 lu is better
# 769 lu is better
# 770 lu is better
# 771 lu is better
# 772 lu is better
# 774 lu is better
# 779 lu is better
# 780 lu is better
# 781 lu is better
# 782 lu is better
# 783 lu is better
# 784 lu is better
# 785 lu is better
# 786 lu is better
# 793 lu is better
# 795 lu is better
# 796 lu is better
# 797 lu is better
# 798 lu is better
# 799 lu is better
# 800 lu is better
# 801 lu is better
# 802 lu is better
# 803 lu is better
# 813 lu is better
# 814 lu is better
# 824 lu is better
# 825 lu is better
# 829 lu is better
# 831 lu is better
# 832 lu is better
# 833 lu is better
# 834 lu is better
# 835 lu is better
# 836 lu is better
# 837 lu is better
# 838 lu is better
# 839 lu is better
# 840 lu is better
# 841 lu is better
# 842 lu is better
# 843 lu is better
# 844 lu is better
# 845 lu is better
# 846 lu is better
# 847 lu is better
# 848 lu is better
# 849 lu is better
# 850 lu is better
# 851 lu is better
# 852 lu is better
# 853 lu is better
# 854 lu is better
# 855 lu is better
# 856 lu is better
# 857 lu is better
# 858 lu is better
# 859 lu is better
# 860 lu is better
# 861 lu is better
# 862 lu is better
# 863 lu is better
# 864 lu is better
# 865 lu is better
# 866 lu is better
# 867 lu is better
# 868 lu is better
# 869 lu is better
# 870 lu is better
# 871 lu is better
# 872 lu is better
# 873 lu is better
# 874 lu is better
# 875 lu is better
# 876 lu is better
# 877 lu is better
# 878 lu is better
# 879 lu is better
# 880 lu is better
# 881 lu is better
# 882 lu is better
# 883 lu is better
# 884 lu is better
# 885 lu is better
# 886 lu is better
# 887 lu is better
# 888 lu is better
# 889 lu is better
# 891 lu is better
# 892 lu is better
# 893 lu is better
# 894 lu is better
# 895 lu is better
# 896 lu is better
# 897 lu is better
# 898 lu is better
# 899 lu is better
# 900 lu is better
# 901 lu is better
# 902 lu is better
# 903 lu is better
# 904 lu is better
# 905 lu is better
# 906 lu is better
# 907 lu is better
# 908 lu is better
# 909 lu is better
# 910 lu is better
# 911 lu is better
# 912 lu is better
# 913 lu is better
# 914 lu is better
# 915 lu is better
# 916 lu is better
# 917 lu is better
# 918 lu is better
# 919 lu is better
# 920 lu is better
# 921 lu is better
# 922 lu is better
# 923 lu is better
# 924 lu is better
# 925 lu is better
# 926 lu is better
# 927 lu is better
# 928 lu is better
# 929 lu is better
# 930 lu is better
# 931 lu is better
# 932 lu is better
# 933 lu is better
# 934 lu is better
# 935 lu is better
# 936 lu is better
# 937 lu is better
# 938 lu is better
# 939 lu is better
# 940 lu is better
# 941 lu is better
# 942 lu is better
# 943 lu is better
# 944 lu is better
# 945 lu is better
# 946 lu is better
# 947 lu is better
# 948 lu is better
# 949 lu is better
# 950 lu is better
# 951 lu is better
# 952 lu is better
# 953 lu is better
# 954 lu is better
# 955 lu is better
# 956 lu is better
# 957 lu is better
# 958 lu is better
# 959 lu is better
# 960 lu is better
# 961 lu is better
# 962 lu is better
# 963 lu is better
# 964 lu is better
# 965 lu is better
# 966 lu is better
# 967 lu is better
# 968 lu is better
# 969 lu is better
# 970 lu is better
# 971 lu is better
# 972 lu is better
# 973 lu is better
# 974 lu is better
# 975 lu is better
# 976 lu is better
# 977 lu is better
# 978 lu is better
# 979 lu is better
# 980 lu is better
# 981 lu is better
# 982 lu is better
# 983 lu is better
# 984 lu is better
# 985 lu is better
# 986 lu is better
# 987 lu is better
# 988 lu is better
# 989 lu is better
# 990 lu is better
# 991 lu is better
# 992 lu is better
# 993 lu is better
# 994 lu is better
# 995 lu is better
# 996 lu is better
# 997 lu is better
# 998 lu is better
